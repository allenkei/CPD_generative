# %% [markdown]
# Simulate data (scenario 3)

# %%
#!python simulate_nn.py --num_node 50
#!python simulate_nn.py --num_node 100

# %% [markdown]
# Simulation study

# %%
# STERGM n50
# !python cpd_latent_sim.py --use_data STERGM --num_node 50

# %%
# STERGM n100
# !python cpd_latent_sim.py --use_data STERGM --num_node 100

# %%
# SBM n50
# !python cpd_latent_sim.py --use_data SBM --num_node 50

# %%
# SBM n100
# !python cpd_latent_sim.py --use_data SBM --num_node 100

# %%
# NN n50
# !python cpd_latent_sim.py --use_data NN --num_node 50

# %%
# NN n100
# !python cpd_latent_sim.py --use_data NN --num_node 100

# %% [markdown]
# Real data experiment

# %%
# !python cpd_latent_real.py --use_data MITphone

# %%
# !python cpd_latent_real.py --use_data Enron
