# %%
# STERGM n50
# !python cpd_latent_sim_gamma.py --use_data STERGM --num_node 50 --latent_dim 5

# %%
# STERGM n100
# !python cpd_latent_sim_gamma.py --use_data STERGM --num_node 100 --latent_dim 10

# %%
# SBM n50
# !python cpd_latent_sim_gamma.py --use_data SBM --num_node 50 --latent_dim 5

# %%
# SBM n100
# !python cpd_latent_sim_gamma.py --use_data SBM --num_node 100 --latent_dim 10

# %%
# NN n50
# !python cpd_latent_sim_gamma.py --use_data NN --num_node 50 --latent_dim 5

# %%
# NN n100
# !python cpd_latent_sim_gamma.py --use_data NN --num_node 100 --latent_dim 10
